# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Metadata

# %%
filename = "data/PVODdatasets/metadata.csv"
df = pd.read_csv(filename)

# %%
df
# Out:
#   Station_ID  Capacity PV_Technology  Panel_Size  \
# 0  station00      6600       Poly-Si     1.62360
# 1  station01     20000       Poly-Si     1.66350
# 2  station02     17000       Mono-Si     1.63680
# 3  station03     20000       Poly-Si     1.62000
# 4  station04     20000       Poly-Si     1.63680
# 5  station05     35000       Poly-Si     1.63515
# 6  station06     15000       Poly-Si     1.63350
# 7  station07     20000       Poly-Si     1.63350
# 8  station08     20000       Poly-Si     1.63350
# 9  station09     20000       Poly-Si     1.61370
#
#                                               Module  \
# 0  products types:LW255(29)P1640×990\nPmax:255 Wp...
# 1  products types:LW6P60-270\nPmax:270 Wp\nVmpp:3...
# 2  products types:RSM60-6-285M\nPmax:285 Wp\nVmpp...
# 3  products types:HTMP265P4-60\nPmax:265 Wp\nVmpp...
# 4  products types:YL265P-29b\nPmax:265 Wp\nVmpp:3...
# 5  products types:LR6-60-305M\nPmax:305 Wp\nVmpp:...
# 6  products types:JAP60S01-270/SC\nPmax:270 Wp\nV...
# 7  products types:YL250P-29b\nPmax:250 Wp\nVmpp:2...
# 8  products types:YL265C-30b\nPmax:265 Wp\nVmpp:3...
# 9  products types:YL265P-29B-265W\nPmax:265 Wp\nV...
#
#                                            Inverters  \
# 0  products types:NSG-500K3TL\nMax. DC input:560 ...
# 1  products types:TC500KH\nMax. DC input:618 kW\n...
# 2  products types:SG50KTL-M\nMax. DC input:-\nMax...
# 3  products types:PVL-L1000E\nMax. DC input:-\nMa...
# 4  products types:SG1000\nMax. DC input:560 kW\nM...
# 5  products types:SG1250UD\nMax. DC input:618 kW\...
# 6  products types:SG50KTL-M\nMax. DC input:-\nMax...
# 7  products types:TC500KH\nMax. DC input:618 kW\n...
# 8  products types:SUN2000-40KTL\nMax. DC input: 4...
# 9  products types:GSL0630T\nMax. DC input:690 kW\...
#
#                                             Layout  Panel_Number Array_Tilt  \
# 0   modules per string:20\nstrings per inverter:96         26000  South 33°
# 1  modules per string:22\nstrings per inverter:128         74000  South 33°
# 2    modules per string:22\nstrings per inverter:8         64064  South 29°
# 3   modules per string:22\nstrings per inverter:16         75460  South 33°
# 4   modules per string:22\nstrings per inverter:86         75680  South 37°
# 5  modules per string:22\nstrings per inverter:160        114972  South 33°
# 6    modules per string:24\nstrings per inverter:8         56608  South 34°
# 7  modules per string:20\nstrings per inverter:100         80000  South 31°
# 8    modules per string:22\nstrings per inverter:5         78042  South 33°
# 9  modules per string:24\nstrings per inverter:128         84480  South 31°
#
#                                          Pyranometer   Longitude   Latitude
# 0  GHI: \nproducts types: TBQ-2\nmeasurement accu...  114.951390  38.047780
# 1  GHI: \nproducts types: TBQ-2\nmeasurement accu...  117.457220  38.183060
# 2  GHI: \nproducts types: TBQ-2\nmeasurement accu...  114.198870  38.057280
# 3  GHI: \nproducts types: TBQ-2L\nmeasurement acc...  114.114940  38.109560
# 4  GHI: \nproducts types: TBQ-2\nmeasurement accu...  114.867670  39.515500
# 5  GHI: \nproducts types: TBQ-2\nmeasurement accu...  114.123600  38.235500
# 6  GHI: \nproducts types: TBQ-2\nmeasurement accu...  114.548410  36.898910
# 7  GHI: \nproducts types: TBQ-2L\nmeasurement acc...  113.641870  36.644030
# 8  GHI: \nproducts types: TBQ-2\nmeasurement accu...  113.899990  36.707610
# 9  GHI: \nproducts types: TBQ-2\nmeasurement accu...  115.059855  38.731417

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Station_ID     10 non-null     object
#  1   Capacity       10 non-null     int64
#  2   PV_Technology  10 non-null     object
#  3   Panel_Size     10 non-null     float64
#  4   Module         10 non-null     object
#  5   Inverters      10 non-null     object
#  6   Layout         10 non-null     object
#  7   Panel_Number   10 non-null     int64
#  8   Array_Tilt     10 non-null     object
#  9   Pyranometer    10 non-null     object
#  10  Longitude      10 non-null     float64
#  11  Latitude       10 non-null     float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.1+ KB

# %% [markdown]
# * Station_ID
# * Capacity
# * PV_Technology
# * Panel_size
# * Module
# * Inverters
# * Layout
# * Panel_Number
# * Array_Tilt
# * Pyranometer
# * Longitude
# * Latitude

# %% [markdown]
# # Dataset

# %%
filename = "data/PVODdatasets/station03.csv"
df = pd.read_csv(filename, header=0)

# %%
df
# Out:
#                  date_time  nwp_globalirrad  nwp_directirrad  nwp_temperature  \
# 0      2019-01-11 16:00:00              0.0              0.0            -0.07
# 1      2019-01-11 16:15:00              0.0              0.0            -0.13
# 2      2019-01-11 16:30:00              0.0              0.0            -0.15
# 3      2019-01-11 16:45:00              0.0              0.0            -0.17
# 4      2019-01-11 17:00:00              0.0              0.0            -0.21
# ...                    ...              ...              ...              ...
# 14683  2019-06-13 14:45:00              0.0              0.0            24.45
# 14684  2019-06-13 15:00:00              0.0              0.0            24.24
# 14685  2019-06-13 15:15:00              0.0              0.0            24.08
# 14686  2019-06-13 15:30:00              0.0              0.0            23.95
# 14687  2019-06-13 15:45:00              0.0              0.0            23.82
#
#        nwp_humidity  nwp_windspeed  nwp_winddirection  nwp_pressure  \
# 0             44.66           1.50             234.97        989.14
# 1             45.23           1.59             238.49        989.14
# 2             45.60           1.67             246.38        989.25
# 3             45.86           1.77             255.51        989.31
# 4             46.08           1.88             262.02        989.08
# ...             ...            ...                ...           ...
# 14683         61.99           4.00             327.25        974.82
# 14684         62.48           4.08             331.59        974.96
# 14685         62.74           4.02             334.14        975.13
# 14686         62.97           3.94             334.80        975.28
# 14687         63.31           3.85             333.20        975.47
#
#        lmd_totalirrad  lmd_diffuseirrad  lmd_temperature  lmd_pressure  \
# 0                   0               0.0        -2.800000    988.500000
# 1                   0               0.0        -2.800000    988.500000
# 2                   0               0.0        -2.800000    988.500000
# 3                   0               0.0        -3.900000    988.500000
# 4                   0               0.0        -3.900000    988.500000
# ...               ...               ...              ...           ...
# 14683               0               0.0        21.799999    972.799988
# 14684               0               0.0        20.700001    972.799988
# 14685               0               0.0        20.700001    972.799988
# 14686               0               0.0        20.700001    972.799988
# 14687               0               0.0        20.700001    972.799988
#
#        lmd_winddirection  lmd_windspeed  power
# 0                     48            1.0    0.0
# 1                    138            1.0    0.0
# 2                     40            1.0    0.0
# 3                    130            1.0    0.0
# 4                    158            1.0    0.0
# ...                  ...            ...    ...
# 14683                 72            0.8    0.0
# 14684                350            0.7    0.0
# 14685                 71            1.0    0.0
# 14686                104            0.0    0.0
# 14687                163            2.4    0.0
#
# [14688 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14688 entries, 0 to 14687
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          14688 non-null  object
#  1   nwp_globalirrad    14688 non-null  float64
#  2   nwp_directirrad    14688 non-null  float64
#  3   nwp_temperature    14688 non-null  float64
#  4   nwp_humidity       14688 non-null  float64
#  5   nwp_windspeed      14688 non-null  float64
#  6   nwp_winddirection  14688 non-null  float64
#  7   nwp_pressure       14688 non-null  float64
#  8   lmd_totalirrad     14688 non-null  int64
#  9   lmd_diffuseirrad   14688 non-null  float64
#  10  lmd_temperature    14688 non-null  float64
#  11  lmd_pressure       14688 non-null  float64
#  12  lmd_winddirection  14688 non-null  int64
#  13  lmd_windspeed      14688 non-null  float64
#  14  power              14688 non-null  float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Position:
# * (Depends on station)
#
# Time:
# * datetime
#
# Weather:
# * nwp_globalirrad
# * nwp_directirrad
# * nwp_temperature
# * nwp_humidity
# * nwp_windspeed
# * nwp_winddirection
# * nwp_pressure
# * lmd_totalirrad
# * lmd_diffuseirrad
# * lmd_temperature
# * lmd_pressure
# * lmd_winddirection
# * lmd_windspeed
#
# Photovoltaics:
# * power

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
sns.heatmap(data=df.corr(),
            annot=True,
            annot_kws={"size": 10},
            square=True,
            cmap='seismic',
            fmt='.2f',
            linewidths=0.5,
            linecolor='w',
            ax=ax)
plt.title('Correlation Analysis')
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.histplot(df[df['power'] != 0].power)  # remove all 0 in histogram
plt.title('Histogram of power')
plt.xlabel('Power ($W/m^2$)')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df['date_time'] = pd.to_datetime(df['date_time'])

# %%
day_of_year = df['date_time'].dt.dayofyear
df['date_sin'] = np.sin(((day_of_year - 1) * 2 * np.pi) / 365)
df['date_cos'] = np.cos(((day_of_year - 1) * 2 * np.pi) / 365)
df
# Out:
#                 date_time  nwp_globalirrad  nwp_directirrad  nwp_temperature  \
# 0     2019-01-11 16:00:00              0.0              0.0            -0.07
# 1     2019-01-11 16:15:00              0.0              0.0            -0.13
# 2     2019-01-11 16:30:00              0.0              0.0            -0.15
# 3     2019-01-11 16:45:00              0.0              0.0            -0.17
# 4     2019-01-11 17:00:00              0.0              0.0            -0.21
# ...                   ...              ...              ...              ...
# 14683 2019-06-13 14:45:00              0.0              0.0            24.45
# 14684 2019-06-13 15:00:00              0.0              0.0            24.24
# 14685 2019-06-13 15:15:00              0.0              0.0            24.08
# 14686 2019-06-13 15:30:00              0.0              0.0            23.95
# 14687 2019-06-13 15:45:00              0.0              0.0            23.82
#
#        nwp_humidity  nwp_windspeed  nwp_winddirection  nwp_pressure  \
# 0             44.66           1.50             234.97        989.14
# 1             45.23           1.59             238.49        989.14
# 2             45.60           1.67             246.38        989.25
# 3             45.86           1.77             255.51        989.31
# 4             46.08           1.88             262.02        989.08
# ...             ...            ...                ...           ...
# 14683         61.99           4.00             327.25        974.82
# 14684         62.48           4.08             331.59        974.96
# 14685         62.74           4.02             334.14        975.13
# 14686         62.97           3.94             334.80        975.28
# 14687         63.31           3.85             333.20        975.47
#
#        lmd_totalirrad  lmd_diffuseirrad  lmd_temperature  lmd_pressure  \
# 0                   0               0.0        -2.800000    988.500000
# 1                   0               0.0        -2.800000    988.500000
# 2                   0               0.0        -2.800000    988.500000
# 3                   0               0.0        -3.900000    988.500000
# 4                   0               0.0        -3.900000    988.500000
# ...               ...               ...              ...           ...
# 14683               0               0.0        21.799999    972.799988
# 14684               0               0.0        20.700001    972.799988
# 14685               0               0.0        20.700001    972.799988
# 14686               0               0.0        20.700001    972.799988
# 14687               0               0.0        20.700001    972.799988
#
#        lmd_winddirection  lmd_windspeed  power  date_sin  date_cos
# 0                     48            1.0    0.0  0.171293  0.985220
# 1                    138            1.0    0.0  0.171293  0.985220
# 2                     40            1.0    0.0  0.171293  0.985220
# 3                    130            1.0    0.0  0.171293  0.985220
# 4                    158            1.0    0.0  0.171293  0.985220
# ...                  ...            ...    ...       ...       ...
# 14683                 72            0.8    0.0  0.329408 -0.944188
# 14684                350            0.7    0.0  0.329408 -0.944188
# 14685                 71            1.0    0.0  0.329408 -0.944188
# 14686                104            0.0    0.0  0.329408 -0.944188
# 14687                163            2.4    0.0  0.329408 -0.944188
#
# [14688 rows x 17 columns]

# %%
minute_of_day = df['date_time'].dt.hour + df['date_time'].dt.minute / 60
df['time_sin'] = np.sin((minute_of_day * 2 * np.pi) / 24)
df['time_cos'] = np.cos((minute_of_day * 2 * np.pi) / 24)
df
# Out:
#                 date_time  nwp_globalirrad  nwp_directirrad  nwp_temperature  \
# 0     2019-01-11 16:00:00              0.0              0.0            -0.07
# 1     2019-01-11 16:15:00              0.0              0.0            -0.13
# 2     2019-01-11 16:30:00              0.0              0.0            -0.15
# 3     2019-01-11 16:45:00              0.0              0.0            -0.17
# 4     2019-01-11 17:00:00              0.0              0.0            -0.21
# ...                   ...              ...              ...              ...
# 14683 2019-06-13 14:45:00              0.0              0.0            24.45
# 14684 2019-06-13 15:00:00              0.0              0.0            24.24
# 14685 2019-06-13 15:15:00              0.0              0.0            24.08
# 14686 2019-06-13 15:30:00              0.0              0.0            23.95
# 14687 2019-06-13 15:45:00              0.0              0.0            23.82
#
#        nwp_humidity  nwp_windspeed  nwp_winddirection  nwp_pressure  \
# 0             44.66           1.50             234.97        989.14
# 1             45.23           1.59             238.49        989.14
# 2             45.60           1.67             246.38        989.25
# 3             45.86           1.77             255.51        989.31
# 4             46.08           1.88             262.02        989.08
# ...             ...            ...                ...           ...
# 14683         61.99           4.00             327.25        974.82
# 14684         62.48           4.08             331.59        974.96
# 14685         62.74           4.02             334.14        975.13
# 14686         62.97           3.94             334.80        975.28
# 14687         63.31           3.85             333.20        975.47
#
#        lmd_totalirrad  lmd_diffuseirrad  lmd_temperature  lmd_pressure  \
# 0                   0               0.0        -2.800000    988.500000
# 1                   0               0.0        -2.800000    988.500000
# 2                   0               0.0        -2.800000    988.500000
# 3                   0               0.0        -3.900000    988.500000
# 4                   0               0.0        -3.900000    988.500000
# ...               ...               ...              ...           ...
# 14683               0               0.0        21.799999    972.799988
# 14684               0               0.0        20.700001    972.799988
# 14685               0               0.0        20.700001    972.799988
# 14686               0               0.0        20.700001    972.799988
# 14687               0               0.0        20.700001    972.799988
#
#        lmd_winddirection  lmd_windspeed  power  date_sin  date_cos  time_sin  \
# 0                     48            1.0    0.0  0.171293  0.985220 -0.866025
# 1                    138            1.0    0.0  0.171293  0.985220 -0.896873
# 2                     40            1.0    0.0  0.171293  0.985220 -0.923880
# 3                    130            1.0    0.0  0.171293  0.985220 -0.946930
# 4                    158            1.0    0.0  0.171293  0.985220 -0.965926
# ...                  ...            ...    ...       ...       ...       ...
# 14683                 72            0.8    0.0  0.329408 -0.944188 -0.659346
# 14684                350            0.7    0.0  0.329408 -0.944188 -0.707107
# 14685                 71            1.0    0.0  0.329408 -0.944188 -0.751840
# 14686                104            0.0    0.0  0.329408 -0.944188 -0.793353
# 14687                163            2.4    0.0  0.329408 -0.944188 -0.831470
#
#        time_cos
# 0     -0.500000
# 1     -0.442289
# 2     -0.382683
# 3     -0.321439
# 4     -0.258819
# ...         ...
# 14683 -0.751840
# 14684 -0.707107
# 14685 -0.659346
# 14686 -0.608761
# 14687 -0.555570
#
# [14688 rows x 19 columns]

# %%
interest_columns = ['lmd_temperature',
                    'lmd_pressure',
                    'lmd_winddirection',
                    'lmd_windspeed',
                    'time_sin',
                    'time_cos',
                    'date_sin',
                    'date_cos']
target_label = ['power']

# %%
df_interested = df[interest_columns + target_label].reset_index(drop=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
sns.heatmap(data=df_interested.corr(),
            annot=True,
            annot_kws={"size": 10},
            square=True,
            cmap='seismic',
            fmt='.2f',
            linewidths=0.5,
            linecolor='w',
            ax=ax)
plt.title('Correlation Analysis')
plt.show()

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(np.array(df_interested[interest_columns]),
                                                    np.ravel(np.array(df_interested[target_label])),
                                                    test_size=0.2,
                                                    random_state=0)

# %%
df_interested
# Out:
#        lmd_temperature  lmd_pressure  lmd_winddirection  lmd_windspeed  \
# 0            -2.800000    988.500000                 48            1.0
# 1            -2.800000    988.500000                138            1.0
# 2            -2.800000    988.500000                 40            1.0
# 3            -3.900000    988.500000                130            1.0
# 4            -3.900000    988.500000                158            1.0
# ...                ...           ...                ...            ...
# 14683        21.799999    972.799988                 72            0.8
# 14684        20.700001    972.799988                350            0.7
# 14685        20.700001    972.799988                 71            1.0
# 14686        20.700001    972.799988                104            0.0
# 14687        20.700001    972.799988                163            2.4
#
#        time_sin  time_cos  date_sin  date_cos  power
# 0     -0.866025 -0.500000  0.171293  0.985220    0.0
# 1     -0.896873 -0.442289  0.171293  0.985220    0.0
# 2     -0.923880 -0.382683  0.171293  0.985220    0.0
# 3     -0.946930 -0.321439  0.171293  0.985220    0.0
# 4     -0.965926 -0.258819  0.171293  0.985220    0.0
# ...         ...       ...       ...       ...    ...
# 14683 -0.659346 -0.751840  0.329408 -0.944188    0.0
# 14684 -0.707107 -0.707107  0.329408 -0.944188    0.0
# 14685 -0.751840 -0.659346  0.329408 -0.944188    0.0
# 14686 -0.793353 -0.608761  0.329408 -0.944188    0.0
# 14687 -0.831470 -0.555570  0.329408 -0.944188    0.0
#
# [14688 rows x 9 columns]

# %%
from sklearn.neural_network import MLPRegressor

data = X_train

target = y_train

mlp = MLPRegressor(hidden_layer_sizes=(200, 100,),
                   early_stopping=True,
                   learning_rate_init=0.003,
                   verbose=1)

mlp.fit(data, target)

y_pred = mlp.predict(X_test)

from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R square score:', metrics.r2_score(y_test, y_pred))
# Out:
# Iteration 1, loss = 626.41665734
# Validation score: -0.362595
# Iteration 2, loss = 9.82406112
# Validation score: 0.320777
# Iteration 3, loss = 7.65034382
# Validation score: 0.398199
# Iteration 4, loss = 6.37825968
# Validation score: 0.509361
# Iteration 5, loss = 5.78887855
# Validation score: 0.584637
# Iteration 6, loss = 4.91262791
# Validation score: 0.629071
# Iteration 7, loss = 5.20995859
# Validation score: 0.591241
# Iteration 8, loss = 4.43274871
# Validation score: 0.660029
# Iteration 9, loss = 4.34229251
# Validation score: 0.665985
# Iteration 10, loss = 4.53923826
# Validation score: 0.671589
# Iteration 11, loss = 4.35679492
# Validation score: 0.658184
# Iteration 12, loss = 4.09439466
# Validation score: 0.671264
# Iteration 13, loss = 4.70413855
# Validation score: 0.671984
# Iteration 14, loss = 4.13114344
# Validation score: 0.680797
# Iteration 15, loss = 4.57524359
# Validation score: 0.515820
# Iteration 16, loss = 4.46837100
# Validation score: 0.660589
# Iteration 17, loss = 4.29741090
# Validation score: 0.684921
# Iteration 18, loss = 4.03890490
# Validation score: 0.675800
# Iteration 19, loss = 4.53066940
# Validation score: 0.622390
# Iteration 20, loss = 4.11674419
# Validation score: 0.640641
# Iteration 21, loss = 4.12447094
# Validation score: 0.658550
# Iteration 22, loss = 4.26664691
# Validation score: 0.666921
# Iteration 23, loss = 4.03991546
# Validation score: 0.676301
# Iteration 24, loss = 4.97700007
# Validation score: 0.662063
# Iteration 25, loss = 4.84385939
# Validation score: 0.687723
# Iteration 26, loss = 4.14211247
# Validation score: 0.683199
# Iteration 27, loss = 5.29905672
# Validation score: 0.682386
# Iteration 28, loss = 4.33126167
# Validation score: 0.596780
# Iteration 29, loss = 4.26703572
# Validation score: 0.563707
# Iteration 30, loss = 4.71842667
# Validation score: 0.644884
# Iteration 31, loss = 4.21504957
# Validation score: 0.692897
# Iteration 32, loss = 4.20008139
# Validation score: 0.686109
# Iteration 33, loss = 4.70999802
# Validation score: 0.579869
# Iteration 34, loss = 4.33847523
# Validation score: 0.697553
# Iteration 35, loss = 4.92014308
# Validation score: 0.679554
# Iteration 36, loss = 4.36455204
# Validation score: 0.673807
# Iteration 37, loss = 4.65217126
# Validation score: 0.470555
# Iteration 38, loss = 4.26300447
# Validation score: 0.640127
# Iteration 39, loss = 4.64639887
# Validation score: 0.680978
# Iteration 40, loss = 5.85922803
# Validation score: 0.255742
# Iteration 41, loss = 5.97876921
# Validation score: 0.708468
# Iteration 42, loss = 5.35861856
# Validation score: 0.497546
# Iteration 43, loss = 4.09889271
# Validation score: 0.707336
# Iteration 44, loss = 5.11084565
# Validation score: 0.715545
# Iteration 45, loss = 4.56602352
# Validation score: 0.714751
# Iteration 46, loss = 4.53756902
# Validation score: 0.668956
# Iteration 47, loss = 3.94759014
# Validation score: 0.741264
# Iteration 48, loss = 6.96668231
# Validation score: 0.630312
# Iteration 49, loss = 5.44027764
# Validation score: 0.716576
# Iteration 50, loss = 3.39305365
# Validation score: 0.755179
# Iteration 51, loss = 3.77070524
# Validation score: 0.480898
# Iteration 52, loss = 4.05620356
# Validation score: 0.690312
# Iteration 53, loss = 3.62764266
# Validation score: 0.707141
# Iteration 54, loss = 3.03509700
# Validation score: 0.637859
# Iteration 55, loss = 3.69016886
# Validation score: 0.379510
# Iteration 56, loss = 3.36069755
# Validation score: 0.760552
# Iteration 57, loss = 3.63756151
# Validation score: 0.631926
# Iteration 58, loss = 3.25049510
# Validation score: 0.581945
# Iteration 59, loss = 3.54877542
# Validation score: 0.770060
# Iteration 60, loss = 3.01290199
# Validation score: 0.795514
# Iteration 61, loss = 3.40179717
# Validation score: -0.090830
# Iteration 62, loss = 3.61127039
# Validation score: 0.763320
# Iteration 63, loss = 2.81341149
# Validation score: 0.801173
# Iteration 64, loss = 2.68466348
# Validation score: 0.800167
# Iteration 65, loss = 3.43378625
# Validation score: 0.630716
# Iteration 66, loss = 3.16464615
# Validation score: 0.813845
# Iteration 67, loss = 2.49043171
# Validation score: 0.814361
# Iteration 68, loss = 4.35491977
# Validation score: 0.788357
# Iteration 69, loss = 3.03608116
# Validation score: 0.804126
# Iteration 70, loss = 2.53488526
# Validation score: 0.755349
# Iteration 71, loss = 3.65230374
# Validation score: 0.710155
# Iteration 72, loss = 2.73940085
# Validation score: 0.805054
# Iteration 73, loss = 3.92601500
# Validation score: 0.606736
# Iteration 74, loss = 2.93317700
# Validation score: 0.768363
# Iteration 75, loss = 2.37010281
# Validation score: 0.808619
# Iteration 76, loss = 2.50817085
# Validation score: 0.726801
# Iteration 77, loss = 3.13481239
# Validation score: 0.798989
# Iteration 78, loss = 2.77885224
# Validation score: 0.816636
# Iteration 79, loss = 3.15452245
# Validation score: 0.818065
# Iteration 80, loss = 2.84998148
# Validation score: 0.795837
# Iteration 81, loss = 3.13849301
# Validation score: 0.422889
# Iteration 82, loss = 2.71921292
# Validation score: 0.819030
# Iteration 83, loss = 2.67966899
# Validation score: 0.773480
# Iteration 84, loss = 2.84335791
# Validation score: 0.798412
# Iteration 85, loss = 2.31942532
# Validation score: 0.814368
# Iteration 86, loss = 2.80338739
# Validation score: 0.795559
# Iteration 87, loss = 2.75288784
# Validation score: 0.811168
# Iteration 88, loss = 2.63823016
# Validation score: 0.812458
# Iteration 89, loss = 2.62103891
# Validation score: 0.774340
# Iteration 90, loss = 2.40580822
# Validation score: 0.824664
# Iteration 91, loss = 2.54359916
# Validation score: 0.707735
# Iteration 92, loss = 2.52364896
# Validation score: 0.801413
# Iteration 93, loss = 2.31207472
# Validation score: 0.820247
# Iteration 94, loss = 2.22750256
# Validation score: 0.817154
# Iteration 95, loss = 2.45060059
# Validation score: 0.816626
# Iteration 96, loss = 2.79830605
# Validation score: 0.778384
# Iteration 97, loss = 3.13933159
# Validation score: 0.790305
# Iteration 98, loss = 2.51201085
# Validation score: 0.812662
# Iteration 99, loss = 2.10255876
# Validation score: 0.761879
# Iteration 100, loss = 2.93390473
# Validation score: 0.791429
# Iteration 101, loss = 2.20925517
# Validation score: 0.799669
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Mean Absolute Error: 1.1180585569852521
# Mean Squared Error: 3.7165913887447677
# Root Mean Squared Error: 1.9278463083826904
# R square score: 0.8440165710311486

# %%
fig, ax = plt.subplots(2, 1, sharex=True, figsize=(80, 4))

ax[0].plot(y_test,
           c="black")
ax[1].plot(y_pred)

plt.show()
